# %%
from pbt import *

# %% [markdown]
# # Asymptotic performance of port-based teleportation
#
# ## Standard protocol for deterministic PBT
#
# Compute the entanglement fidelity for $N$ ports with local dimension $d$ and compare with the asymptotic behavior:

# %%
print_det_std(d=2, N_min=10, N_max=250)
# Out:
# N F O
# 10 0.925790178051747 0.742098219482527
# 20 0.963715511678486 0.725689766430289
# 30 0.975571654098106 0.732850377056831
# 40 0.981579259690986 0.736829612360546
# 50 0.985213629151039 0.739318542448070
# 60 0.987649685610112 0.741018863393286
# 70 0.989396382804380 0.742253203693406
# 80 0.990710128573209 0.743189714143320
# 90 0.991734172762379 0.743924451385853
# 100 0.992554837790144 0.744516220985647
# 110 0.993227245269384 0.745003020367748
# 120 0.993788245941425 0.745410487028986
# 130 0.994263411208136 0.745756542942292
# 140 0.994671042197304 0.746054092377477
# 150 0.995024582251425 0.746312662286286
# 160 0.995334128506732 0.746539438922955
# 170 0.995607412088985 0.746739944872520
# 180 0.995850452811038 0.746918494013078
# 190 0.996068007868642 0.747078504957952
# 200 0.996263886391031 0.747222721793706
# 210 0.996441174416241 0.747353372589478
# 220 0.996602398703529 0.747472285223556
# 230 0.996749647941925 0.747580973357276
# ...

# %%
F_std_coeff(d=2).n()
# Out:
# 0.750000000000000

# %% [markdown]
# ## Probabilistic PBT with EPR pairs
#
# Compute the probability of success for probabilistic PBT using EPR pairs and $N$ ports with local dimension $d$, as well as the asymptotic behavior.

# %%
print_prob_epr(d=2, N_min=10, N_max=500)
# Out:
# N p FO
# 10 0.598721590909091 0.8512400526357939
# 20 0.695224943615141 0.939379812667241
# 30 0.743329168327393 0.9773734084559812
# 40 0.773648868663281 0.999539531894337
# 50 0.795057497818821 1.0144136313195546
# 60 0.811237096605812 1.02524499222635
# 70 0.824033559961178 1.0335688108141619
# 80 0.834489921464531 1.0402147138087754
# 90 0.843246765011590 1.0456745010902115
# 100 0.850722515324652 1.0502602000620773
# 110 0.857203792605575 1.0541803679255395
# 120 0.862894504989684 1.05758027938328
# 130 0.867944266402691 1.0605645817426965
# 140 0.872465709484295 1.063210783610396
# 150 0.876545487584933 1.0655776552440097
# 160 0.880251518550620 1.0677106608767604
# 170 0.883637900401164 1.069645586092736
# 180 0.886748335296968 1.071411027776788
# 190 0.889618569355172 1.0730301448926276
# 200 0.892278166359596 1.0745219158135655
# 210 0.894751820338421 1.0759020583477579
# 220 0.897060342438345 1.0771837142895937
# 230 0.899221413579917 1.0783779664640107
# ...

# %%
sqrt(4/pi).n()
# Out:
# 1.12837916709551

# %% [markdown]
# ### References
#
# [CLM+18] M. Christandl, F. Leditzky, C. Majenz, G. Smith, F. Speelman, M. Walter, "Asymptotic performance of port-based teleportation", 2018. [arXiv:1809.10751](https://arxiv.org/abs/1809.10751)
#
# [SSMH17] M. Studzinski, S. Strelchuk, M. Mozrzymas, M. Horodecki, "Port-based teleportation in arbitrary dimension", Scientific Reports 7 (2017). [arXiv:1612.09260](https://arxiv.org/abs/1612.09260)
